# %%
# !pip install IPython
# Out:
# Requirement already satisfied: IPython in c:\users\asus\anaconda3\lib\site-packages (8.10.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\asus\anaconda3\lib\site-packages (from IPython) (2.11.2)
# Requirement already satisfied: traitlets>=5 in c:\users\asus\anaconda3\lib\site-packages (from IPython) (5.7.1)
# Requirement already satisfied: matplotlib-inline in c:\users\asus\anaconda3\lib\site-packages (from IPython) (0.1.6)
# Requirement already satisfied: jedi>=0.16 in c:\users\asus\anaconda3\lib\site-packages (from IPython) (0.18.1)
# Requirement already satisfied: decorator in c:\users\asus\anaconda3\lib\site-packages (from IPython) (5.1.1)
# Requirement already satisfied: stack-data in c:\users\asus\anaconda3\lib\site-packages (from IPython) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\asus\anaconda3\lib\site-packages (from IPython) (0.7.5)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from IPython) (0.4.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\asus\anaconda3\lib\site-packages (from IPython) (3.0.36)
# Requirement already satisfied: backcall in c:\users\asus\anaconda3\lib\site-packages (from IPython) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\asus\anaconda3\lib\site-packages (from jedi>=0.16->IPython) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\asus\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->IPython) (0.2.5)
# Requirement already satisfied: executing in c:\users\asus\anaconda3\lib\site-packages (from stack-data->IPython) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\asus\anaconda3\lib\site-packages (from stack-data->IPython) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\asus\anaconda3\lib\site-packages (from stack-data->IPython) (0.2.2)
# Requirement already satisfied: six in c:\users\asus\anaconda3\lib\site-packages (from asttokens->stack-data->IPython) (1.16.0)

# %%
# !pip install tabulate
# Out:
# Requirement already satisfied: tabulate in c:\users\asus\anaconda3\lib\site-packages (0.8.10)

# %%
import csv
from IPython.display import display, HTML

# 读取CSV文件
filename = '中部老街.csv'
rows = []
with open(filename, 'r', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        rows.append(row)

# 创建可点击的超链接并对齐表格
html_table = "<table><tr>{}</tr>".format(
    ''.join(["<th>{}</th>".format(key) for key in rows[0].keys()]))

for row in rows:
    html_table += "<tr>"
    for col, val in row.items():
        if col == "Google Map":
            html_table += f'<td><a href="{val}" target="_blank">{val}</a></td>'
        else:
            html_table += f'<td>{val}</td>'
    html_table += "</tr>"

html_table += "</table>"

# 在Jupyter Notebook上显示表格
display(HTML(html_table))
# Out:
# <table><tr><th>﻿老街名稱</th><th>地址</th><th>景點特色</th><th>必吃美食</th><th>大眾交通</th><th>Google Map</th></tr><tr><td>廣盛老街</td><td>苗栗縣三義鄉廣盛老街</td><td>1.3D彩繪天梯
# 2.具有客家精神的圖騰塗鴉</td><td>廣盛老街糕餅，廣盛豆干，紅茶凍奶</td><td>可搭乘台中市公車至「廣盛」站下車，步行即可抵達。</td><td><a href="https://maps.app.goo.gl/Q66NTjhKVJ9P231t6" target="_blank">https://maps.app.goo.gl/Q66NTjhKVJ9P231t6</a></td></tr><tr><td>南屯老街</td><td>台中市南屯區南屯路二段676號</td><td>1.老廟福德寺、古蹟萬和宮
# 2. 紅磚老店永成雜貨店</td><td>南屯酥餅，豬血糕湯，南屯豆花</td><td>可搭乘台中市公車至「南屯區公所」站下車，步行即可抵達。</td><td><a href="https://maps.app.goo.gl/XVog9S8a5GNBcPhE8" target="_blank">https://maps.app.goo.gl/XVog9S8a5GNBcPhE8</a></td></tr><tr><td>梧棲老街</td><td>台中市梧棲區梧棲老街</td><td>1.彩繪互動牆
# 2.百年廟宇和日式特色建築</td><td>梧棲米糕，鱔魚意麵，梧棲紅茶</td><td>可搭乘台中市公車至「梧棲」站下車，步行即可抵達。</td><td><a href="https://maps.app.goo.gl/79WJCYMELGEKGwWL9" target="_blank">https://maps.app.goo.gl/79WJCYMELGEKGwWL9</a></td></tr><tr><td>大里老街</td><td>台中市大里區大里老街</td><td>1.亭仔腳式街屋建築
# 2.大里杙碼頭遺址</td><td>大里肉圓，大里米糕湯，麻辣火雞腳</td><td>可搭乘台中市公車至「大里轉運站」，再轉乘市區公車或步行至大里老街。</td><td><a href="https://maps.app.goo.gl/WVhy4UmPxBNCCEKZ8" target="_blank">https://maps.app.goo.gl/WVhy4UmPxBNCCEKZ8</a></td></tr><tr><td>鹿港老街</td><td>彰化縣鹿港鎮瑤林街9號</td><td>1.閩南風味古早老宅
# 2.可以穿旗袍光逛街</td><td>鹿港香腸，魚丸湯，草仔粿</td><td>可搭乘高鐵至「嘉義高鐵站」，再轉乘巴士至「鹿港」站下車，步行即可抵達鹿港老街。</td><td><a href="https://maps.app.goo.gl/6S3ycvNa2X4CeZk77" target="_blank">https://maps.app.goo.gl/6S3ycvNa2X4CeZk77</a></td></tr><tr><td>斗六太平老街</td><td>雲林縣斗六市太平路123號</td><td>1.巴洛克式風格建築
# 2.三級古蹟</td><td>太平麻糬，斗六米糕，豆花冰</td><td>可搭乘火車至「斗六火車站」，再轉乘市區公車或步行至太平老街。</td><td><a href="https://maps.app.goo.gl/kZigMpXPEkSJQfyP6" target="_blank">https://maps.app.goo.gl/kZigMpXPEkSJQfyP6</a></td></tr><tr><td>西螺延平老街</td><td>雲林縣西螺鎮延平路130號往東</td><td>1.福興宮
# 2.捷發乾記茶莊，最豪華洋樓</td><td>延平鹹酥雞，蚵仔煎，西螺米糕</td><td>可搭乘火車至「西螺火車站」，再轉乘市區公車或步行至延平老街。</td><td><a href="https://maps.app.goo.gl/UUqC3A4H3DkinKqw7" target="_blank">https://maps.app.goo.gl/UUqC3A4H3DkinKqw7</a></td></tr><tr><td>北港老街</td><td>雲林縣北港鎮中山路</td><td>1.北港朝天宮
# 2.日興堂喜餅</td><td>北港肉圓，北港米糕，蓮霧冰</td><td>可搭乘火車至「北港火車站」，步行即可抵達北港老街。</td><td><a href="https://maps.app.goo.gl/MX3D6fexggcNQNkR8" target="_blank">https://maps.app.goo.gl/MX3D6fexggcNQNkR8</a></td></tr><tr><td>伊達邵碼頭老街</td><td>南投縣魚池鄉義勇街78號</td><td>1.邵族文化老街
# 2.在日月潭周圍</td><td>海鮮炒飯，蚵仔煎，炸物拼盤</td><td>可搭乘火車至「伊達邵火車站」，再轉乘市區公車或步行至伊達邵碼頭老街。</td><td><a href="https://maps.app.goo.gl/68QSr1cRk44fHqZC8" target="_blank">https://maps.app.goo.gl/68QSr1cRk44fHqZC8</a></td></tr></table>

# %%
# !pip install folium geopy
# Out:
# Requirement already satisfied: folium in c:\users\asus\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: geopy in c:\users\asus\anaconda3\lib\site-packages (2.3.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\asus\anaconda3\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: numpy in c:\users\asus\anaconda3\lib\site-packages (from folium) (1.23.5)
# Requirement already satisfied: requests in c:\users\asus\anaconda3\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\asus\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\asus\anaconda3\lib\site-packages (from geopy) (2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\lib\site-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\asus\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests->folium) (1.26.14)

# %%
 import folium

# 创建地图对象
map_center = [24.44987455454395, 120.77104088677899]  # 地图中心点的经纬度坐标
zoom_level = 14  # 地图缩放级别
map_obj = folium.Map(location=map_center, zoom_start=zoom_level)

# 在地图上标记地址
address = "苗栗縣三義鄉廣盛老街"
location = [24.44987455454395, 120.77104088677899]  # 地址的经纬度坐标
name = "廣盛老街"
marker = folium.Marker(location=location, popup=address, tooltip=name)
marker.add_to(map_obj)

# 显示地图
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_076f99bcf47924f0163197c96f7028d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_076f99bcf47924f0163197c96f7028d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_076f99bcf47924f0163197c96f7028d4 = L.map(
#                 &quot;map_076f99bcf47924f0163197c96f7028d4&quot;,
#                 {
#                     center: [24.44987455454395, 120.77104088677899],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_820758b63365e3341168f915175b34ba = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_076f99bcf47924f0163197c96f7028d4);
#
#
#             var marker_742858679a9c2eb1b09f945343d11006 = L.marker(
#                 [24.44987455454395, 120.77104088677899],
#                 {}
#             ).addTo(map_076f99bcf47924f0163197c96f7028d4);
#
#
#         var popup_7474ebaa978d7e64409ce8f3c24e32e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_396ac6f6e27a5176ffb1d797540f826f = $(`&lt;div id=&quot;html_396ac6f6e27a5176ffb1d797540f826f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;苗栗縣三義鄉廣盛老街&lt;/div&gt;`)[0];
#                 popup_7474ebaa978d7e64409ce8f3c24e32e4.setContent(html_396ac6f6e27a5176ffb1d797540f826f);
#
#
#
#         marker_742858679a9c2eb1b09f945343d11006.bindPopup(popup_7474ebaa978d7e64409ce8f3c24e32e4)
#         ;
#
#
#
#
#             marker_742858679a9c2eb1b09f945343d11006.bindTooltip(
#                 `&lt;div&gt;
#                      廣盛老街
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
 import folium

# 创建地图对象
map_center = [24.1392712513721, 120.63961523718429]  # 地图中心点的经纬度坐标
zoom_level = 14  # 地图缩放级别
map_obj = folium.Map(location=map_center, zoom_start=zoom_level)

# 在地图上标记地址
address = "台中市南屯區南屯路二段676號"
location = [24.1392712513721, 120.63961523718429]  # 地址的经纬度坐标
name = "南屯老街"
marker = folium.Marker(location=location, popup=address, tooltip=name)
marker.add_to(map_obj)

# 显示地图
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae070f52049ffaa791386328e8f72d0d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae070f52049ffaa791386328e8f72d0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae070f52049ffaa791386328e8f72d0d = L.map(
#                 &quot;map_ae070f52049ffaa791386328e8f72d0d&quot;,
#                 {
#                     center: [24.1392712513721, 120.63961523718429],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_377d331452bf467de09adabbdd11336c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ae070f52049ffaa791386328e8f72d0d);
#
#
#             var marker_bafba24f33398f98558466da29e59105 = L.marker(
#                 [24.1392712513721, 120.63961523718429],
#                 {}
#             ).addTo(map_ae070f52049ffaa791386328e8f72d0d);
#
#
#         var popup_c7d89cceb09d156121daa14d5315f07f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1b4d559e2bb028c210f0e4d1a57aa354 = $(`&lt;div id=&quot;html_1b4d559e2bb028c210f0e4d1a57aa354&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;台中市南屯區南屯路二段676號&lt;/div&gt;`)[0];
#                 popup_c7d89cceb09d156121daa14d5315f07f.setContent(html_1b4d559e2bb028c210f0e4d1a57aa354);
#
#
#
#         marker_bafba24f33398f98558466da29e59105.bindPopup(popup_c7d89cceb09d156121daa14d5315f07f)
#         ;
#
#
#
#
#             marker_bafba24f33398f98558466da29e59105.bindTooltip(
#                 `&lt;div&gt;
#                      南屯老街
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
 import folium

# 创建地图对象
map_center = [24.25676428754518, 120.52967665623115]  # 地图中心点的经纬度坐标
zoom_level = 14  # 地图缩放级别
map_obj = folium.Map(location=map_center, zoom_start=zoom_level)

# 在地图上标记地址
address = "台中市梧棲區梧棲老街"
location = [24.25676428754518, 120.52967665623115]  # 地址的经纬度坐标
name = "梧棲老街"
marker = folium.Marker(location=location, popup=address, tooltip=name)
marker.add_to(map_obj)

# 显示地图
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2417c4fc1bd044007ec89b4068ae17c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2417c4fc1bd044007ec89b4068ae17c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2417c4fc1bd044007ec89b4068ae17c = L.map(
#                 &quot;map_e2417c4fc1bd044007ec89b4068ae17c&quot;,
#                 {
#                     center: [24.25676428754518, 120.52967665623115],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_167db3e34032fd493ad594a9a869ef33 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e2417c4fc1bd044007ec89b4068ae17c);
#
#
#             var marker_76a197873fb32badafd306346d52f1fb = L.marker(
#                 [24.25676428754518, 120.52967665623115],
#                 {}
#             ).addTo(map_e2417c4fc1bd044007ec89b4068ae17c);
#
#
#         var popup_a2800c00fea44b51d34248b2aaaf6e28 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_670d5b12e37d2a6db473c9e1cdb9bbd5 = $(`&lt;div id=&quot;html_670d5b12e37d2a6db473c9e1cdb9bbd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;台中市梧棲區梧棲老街&lt;/div&gt;`)[0];
#                 popup_a2800c00fea44b51d34248b2aaaf6e28.setContent(html_670d5b12e37d2a6db473c9e1cdb9bbd5);
#
#
#
#         marker_76a197873fb32badafd306346d52f1fb.bindPopup(popup_a2800c00fea44b51d34248b2aaaf6e28)
#         ;
#
#
#
#
#             marker_76a197873fb32badafd306346d52f1fb.bindTooltip(
#                 `&lt;div&gt;
#                      梧棲老街
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# 创建地图对象
map_center = [24.097663812028156, 120.6773358236896]  # 地图中心点的经纬度坐标
zoom_level = 14  # 地图缩放级别
map_obj = folium.Map(location=map_center, zoom_start=zoom_level)

# 在地图上标记地址
address = "台中市大里區大里老街"
location = [24.097663812028156, 120.6773358236896]  # 地址的经纬度坐标
name = "大里老街"
marker = folium.Marker(location=location, popup=address, tooltip=name)
marker.add_to(map_obj)

# 显示地图
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f57696e643cf15ac501126c5be210764 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f57696e643cf15ac501126c5be210764&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f57696e643cf15ac501126c5be210764 = L.map(
#                 &quot;map_f57696e643cf15ac501126c5be210764&quot;,
#                 {
#                     center: [24.097663812028156, 120.6773358236896],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10cb3c9f6d810f5363e0d5eb3ce66bdd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f57696e643cf15ac501126c5be210764);
#
#
#             var marker_40383532a0f117b4e4d3b5317f048670 = L.marker(
#                 [24.097663812028156, 120.6773358236896],
#                 {}
#             ).addTo(map_f57696e643cf15ac501126c5be210764);
#
#
#         var popup_99f26f0b695fc74ce5c26bd927dda403 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21714c8adebe1eb7db2d5f3c0e040b85 = $(`&lt;div id=&quot;html_21714c8adebe1eb7db2d5f3c0e040b85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;台中市大里區大里老街&lt;/div&gt;`)[0];
#                 popup_99f26f0b695fc74ce5c26bd927dda403.setContent(html_21714c8adebe1eb7db2d5f3c0e040b85);
#
#
#
#         marker_40383532a0f117b4e4d3b5317f048670.bindPopup(popup_99f26f0b695fc74ce5c26bd927dda403)
#         ;
#
#
#
#
#             marker_40383532a0f117b4e4d3b5317f048670.bindTooltip(
#                 `&lt;div&gt;
#                      大里老街
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# 创建地图对象
map_center = [24.05661448164748, 120.43258169485239]  # 地图中心点的经纬度坐标
zoom_level = 14  # 地图缩放级别
map_obj = folium.Map(location=map_center, zoom_start=zoom_level)

# 在地图上标记地址
address = "彰化縣鹿港鎮瑤林街9號"
location = [24.05661448164748, 120.43258169485239]  # 地址的经纬度坐标
name = "鹿港老街"
marker = folium.Marker(location=location, popup=address, tooltip=name)
marker.add_to(map_obj)

# 显示地图
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00d9f7e87fa3dab04fafc1d9fefce056 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00d9f7e87fa3dab04fafc1d9fefce056&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00d9f7e87fa3dab04fafc1d9fefce056 = L.map(
#                 &quot;map_00d9f7e87fa3dab04fafc1d9fefce056&quot;,
#                 {
#                     center: [24.05661448164748, 120.43258169485239],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08dc8bb0f9b49260fbb068f1f5cc3121 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_00d9f7e87fa3dab04fafc1d9fefce056);
#
#
#             var marker_89e0c3a0f7b6f1dc28271bd068338dd4 = L.marker(
#                 [24.05661448164748, 120.43258169485239],
#                 {}
#             ).addTo(map_00d9f7e87fa3dab04fafc1d9fefce056);
#
#
#         var popup_f66a750abbf06f32308f42a11b06bf13 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b996fe173771515868d158bfcbaa0f04 = $(`&lt;div id=&quot;html_b996fe173771515868d158bfcbaa0f04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;彰化縣鹿港鎮瑤林街9號&lt;/div&gt;`)[0];
#                 popup_f66a750abbf06f32308f42a11b06bf13.setContent(html_b996fe173771515868d158bfcbaa0f04);
#
#
#
#         marker_89e0c3a0f7b6f1dc28271bd068338dd4.bindPopup(popup_f66a750abbf06f32308f42a11b06bf13)
#         ;
#
#
#
#
#             marker_89e0c3a0f7b6f1dc28271bd068338dd4.bindTooltip(
#                 `&lt;div&gt;
#                      鹿港老街
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# 创建地图对象
map_center = [23.70874290902979, 120.54186079696086]  # 地图中心点的经纬度坐标
zoom_level = 14  # 地图缩放级别
map_obj = folium.Map(location=map_center, zoom_start=zoom_level)

# 在地图上标记地址
address = "雲林縣斗六市太平路123號"
location = [23.70874290902979, 120.54186079696086]  # 地址的经纬度坐标
name = "斗六太平老街"
marker = folium.Marker(location=location, popup=address, tooltip=name)
marker.add_to(map_obj)

# 显示地图
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7fc5436670ddd6fef7d4f49b9bfa180f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7fc5436670ddd6fef7d4f49b9bfa180f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7fc5436670ddd6fef7d4f49b9bfa180f = L.map(
#                 &quot;map_7fc5436670ddd6fef7d4f49b9bfa180f&quot;,
#                 {
#                     center: [23.70874290902979, 120.54186079696086],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53fc52ec22eaa4a91dcca84c93d61ccb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7fc5436670ddd6fef7d4f49b9bfa180f);
#
#
#             var marker_01c9192c12f864f8ca8e94dd17ac9cac = L.marker(
#                 [23.70874290902979, 120.54186079696086],
#                 {}
#             ).addTo(map_7fc5436670ddd6fef7d4f49b9bfa180f);
#
#
#         var popup_b9e77376ddb4ae987fa4abf02d6170ad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b90148e46245555df83f69df559d8d75 = $(`&lt;div id=&quot;html_b90148e46245555df83f69df559d8d75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;雲林縣斗六市太平路123號&lt;/div&gt;`)[0];
#                 popup_b9e77376ddb4ae987fa4abf02d6170ad.setContent(html_b90148e46245555df83f69df559d8d75);
#
#
#
#         marker_01c9192c12f864f8ca8e94dd17ac9cac.bindPopup(popup_b9e77376ddb4ae987fa4abf02d6170ad)
#         ;
#
#
#
#
#             marker_01c9192c12f864f8ca8e94dd17ac9cac.bindTooltip(
#                 `&lt;div&gt;
#                      斗六太平老街
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# 创建地图对象
map_center = [23.80161431434295, 120.46192590278613]  # 地图中心点的经纬度坐标
zoom_level = 14  # 地图缩放级别
map_obj = folium.Map(location=map_center, zoom_start=zoom_level)

# 在地图上标记地址
address = "雲林縣西螺鎮延平路130號往東"
location = [23.80161431434295, 120.46192590278613]  # 地址的经纬度坐标
name = "西螺延平老街"
marker = folium.Marker(location=location, popup=address, tooltip=name)
marker.add_to(map_obj)

# 显示地图
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf7edb8b08bd3c26942cee82afb72388 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf7edb8b08bd3c26942cee82afb72388&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf7edb8b08bd3c26942cee82afb72388 = L.map(
#                 &quot;map_cf7edb8b08bd3c26942cee82afb72388&quot;,
#                 {
#                     center: [23.80161431434295, 120.46192590278613],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3710978cd0e8247adfff2b0f76bf693 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cf7edb8b08bd3c26942cee82afb72388);
#
#
#             var marker_7649aa30182b99eddcf70277b3a32171 = L.marker(
#                 [23.80161431434295, 120.46192590278613],
#                 {}
#             ).addTo(map_cf7edb8b08bd3c26942cee82afb72388);
#
#
#         var popup_cb00ed5638d574dc91a7ad493293b910 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5a211161d6138754ed67b29afb72aaed = $(`&lt;div id=&quot;html_5a211161d6138754ed67b29afb72aaed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;雲林縣西螺鎮延平路130號往東&lt;/div&gt;`)[0];
#                 popup_cb00ed5638d574dc91a7ad493293b910.setContent(html_5a211161d6138754ed67b29afb72aaed);
#
#
#
#         marker_7649aa30182b99eddcf70277b3a32171.bindPopup(popup_cb00ed5638d574dc91a7ad493293b910)
#         ;
#
#
#
#
#             marker_7649aa30182b99eddcf70277b3a32171.bindTooltip(
#                 `&lt;div&gt;
#                      西螺延平老街
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# 创建地图对象
map_center = [23.564556833039898, 120.30394113716171]  # 地图中心点的经纬度坐标
zoom_level = 14  # 地图缩放级别
map_obj = folium.Map(location=map_center, zoom_start=zoom_level)

# 在地图上标记地址
address = "雲林縣北港鎮中山路"
location = [23.564556833039898, 120.30394113716171]  # 地址的经纬度坐标
name = "北港老街"
marker = folium.Marker(location=location, popup=address, tooltip=name)
marker.add_to(map_obj)

# 显示地图
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ceb0375f501aafc0abe65e9cf5145d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ceb0375f501aafc0abe65e9cf5145d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ceb0375f501aafc0abe65e9cf5145d9 = L.map(
#                 &quot;map_3ceb0375f501aafc0abe65e9cf5145d9&quot;,
#                 {
#                     center: [23.564556833039898, 120.30394113716171],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ffb2581886798093df17190fa1d8ab9d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3ceb0375f501aafc0abe65e9cf5145d9);
#
#
#             var marker_239e13be355e06e3271002e1ba81d7ad = L.marker(
#                 [23.564556833039898, 120.30394113716171],
#                 {}
#             ).addTo(map_3ceb0375f501aafc0abe65e9cf5145d9);
#
#
#         var popup_fa2b503de112e0e0a324f1b18c3d7a76 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_82e2a9a99efac422c02f9ea8e6e8a182 = $(`&lt;div id=&quot;html_82e2a9a99efac422c02f9ea8e6e8a182&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;雲林縣北港鎮中山路&lt;/div&gt;`)[0];
#                 popup_fa2b503de112e0e0a324f1b18c3d7a76.setContent(html_82e2a9a99efac422c02f9ea8e6e8a182);
#
#
#
#         marker_239e13be355e06e3271002e1ba81d7ad.bindPopup(popup_fa2b503de112e0e0a324f1b18c3d7a76)
#         ;
#
#
#
#
#             marker_239e13be355e06e3271002e1ba81d7ad.bindTooltip(
#                 `&lt;div&gt;
#                      北港老街
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# 创建地图对象
map_center = [23.84812574530763, 120.93110234799886]  # 地图中心点的经纬度坐标
zoom_level = 14  # 地图缩放级别
map_obj = folium.Map(location=map_center, zoom_start=zoom_level)

# 在地图上标记地址
address = "南投縣魚池鄉義勇街78號"
location = [23.84812574530763, 120.93110234799886]  # 地址的经纬度坐标
name = "伊達邵碼頭老街"
marker = folium.Marker(location=location, popup=address, tooltip=name)
marker.add_to(map_obj)

# 显示地图
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee5742ded65077575d9be381480d37b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee5742ded65077575d9be381480d37b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee5742ded65077575d9be381480d37b6 = L.map(
#                 &quot;map_ee5742ded65077575d9be381480d37b6&quot;,
#                 {
#                     center: [23.84812574530763, 120.93110234799886],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e640df40e5b01ee3741e546cf1a15d2b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ee5742ded65077575d9be381480d37b6);
#
#
#             var marker_c0e77cecc92ca5d7ef32f8301bb9dcb3 = L.marker(
#                 [23.84812574530763, 120.93110234799886],
#                 {}
#             ).addTo(map_ee5742ded65077575d9be381480d37b6);
#
#
#         var popup_e7c20a35b788f803d787a529154f0b2e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_03797a2ddbc1348dab9b6060fad44a57 = $(`&lt;div id=&quot;html_03797a2ddbc1348dab9b6060fad44a57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;南投縣魚池鄉義勇街78號&lt;/div&gt;`)[0];
#                 popup_e7c20a35b788f803d787a529154f0b2e.setContent(html_03797a2ddbc1348dab9b6060fad44a57);
#
#
#
#         marker_c0e77cecc92ca5d7ef32f8301bb9dcb3.bindPopup(popup_e7c20a35b788f803d787a529154f0b2e)
#         ;
#
#
#
#
#             marker_c0e77cecc92ca5d7ef32f8301bb9dcb3.bindTooltip(
#                 `&lt;div&gt;
#                      伊達邵碼頭老街
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
