# %%
# !pip install IPython

# %%
# !pip install tabulate

# %%
import csv
from IPython.display import display, HTML

# 读取CSV文件
filename = '北部老街.csv'
rows = []
with open(filename, 'r', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        rows.append(row)

# 创建可点击的超链接并对齐表格
html_table = "<table><tr>{}</tr>".format(
    ''.join(["<th>{}</th>".format(key) for key in rows[0].keys()]))

for row in rows:
    html_table += "<tr>"
    for col, val in row.items():
        if col == "Google Map":
            html_table += f'<td><a href="{val}" target="_blank">{val}</a></td>'
        else:
            html_table += f'<td>{val}</td>'
    html_table += "</tr>"

html_table += "</table>"

# 在Jupyter Notebook上显示表格
display(HTML(html_table))
# Out:
# <table><tr><th>﻿老街名稱</th><th>地址</th><th>景點特色</th><th>必吃美食</th><th>大眾交通</th><th>Google Map</th></tr><tr><td>九份老街</td><td>新北市瑞芳區基山街</td><td>1.山城小鎮
# 2.台灣知名電影【悲情城市】拍攝地</td><td>阿柑姨芋園、阿蘭草仔粿、護理長滷味、紅糟肉圓、魚丸湯</td><td>搭火車至瑞芳火車站，轉搭前往九份的公車路線為：825、1062</td><td><a href="https://maps.app.goo.gl/5c1ocMMDBTdCbYar7" target="_blank">https://maps.app.goo.gl/5c1ocMMDBTdCbYar7</a></td></tr><tr><td>十分老街</td><td>新北市平溪區十分街</td><td>1.天燈故鄉
# 2.十分瀑布，台灣最大的簾幕式瀑布</td><td>楊家雞捲、溜哥炭烤雞翅包飯、周萬珍餅店、豪哥肉麻麵</td><td>搭乘火車平溪支線，在十分站下車；或從捷運木柵站轉乘「台灣好行795公車 – 木柵平溪線」（往十分）至十分寮橋站下車</td><td><a href="https://maps.app.goo.gl/mWWJXHeVTX91Gkit7" target="_blank">https://maps.app.goo.gl/mWWJXHeVTX91Gkit7</a></td></tr><tr><td>金山老街</td><td>新北市金山區金包里街</td><td>1.有三百多年歷史
# ...

# %%
# !pip install folium geopy
# Out:
# ...
#      ------------------------------------ 102.3/102.3 kB 836.7 kB/s eta 0:00:00
# ...
#      -------------------------------------- 119.8/119.8 kB 1.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 40.3/40.3 kB ? eta 0:00:00
# ...

# %%
 import folium

# 创建地图对象
map_center = [25.109995771595642, 121.84524706790877]  # 地图中心点的经纬度坐标
zoom_level = 14  # 地图缩放级别
map_obj = folium.Map(location=map_center, zoom_start=zoom_level)

# 在地图上标记地址
address = "新北市瑞芳區基山街"
location = [25.109995771595642, 121.84524706790877]  # 地址的经纬度坐标
name = "九份老街"
marker = folium.Marker(location=location, popup=address, tooltip=name)
marker.add_to(map_obj)

# 显示地图
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

# 创建地图对象
map_center = [25.042872802851445, 121.77658986420656]  # 地图中心点的经纬度坐标
zoom_level = 14  # 地图缩放级别
map_obj = folium.Map(location=map_center, zoom_start=zoom_level)

# 在地图上标记地址
address = "新北市平溪區十分街"
location = [25.042872802851445, 121.77658986420656]  # 地址的经纬度坐标
name = "十分老街"
marker = folium.Marker(location=location, popup=address, tooltip=name)
marker.add_to(map_obj)

# 显示地图
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

# 创建地图对象
map_center = [25.221999207877747, 121.63825617100363]  # 地图中心点的经纬度坐标
zoom_level = 14  # 地图缩放级别
map_obj = folium.Map(location=map_center, zoom_start=zoom_level)

# 在地图上标记地址
address = "新北市金山區金包里街"
location = [25.221999207877747, 121.63825617100363]  # 地址的经纬度坐标
name = "金山老街"
marker = folium.Marker(location=location, popup=address, tooltip=name)
marker.add_to(map_obj)

# 显示地图
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

# 创建地图对象
map_center = [25.16916973291003, 121.44400626421175]  # 地图中心点的经纬度坐标
zoom_level = 14  # 地图缩放级别
map_obj = folium.Map(location=map_center, zoom_start=zoom_level)

# 在地图上标记地址
address = "新北市淡水區中正路、重建街、清水街一帶"
location = [25.16916973291003, 121.44400626421175]  # 地址的经纬度坐标
name = "淡水老街"
marker = folium.Marker(location=location, popup=address, tooltip=name)
marker.add_to(map_obj)

# 显示地图
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

# 创建地图对象
map_center = [25.001905494510424, 121.61478061023307]  # 地图中心点的经纬度坐标
zoom_level = 14  # 地图缩放级别
map_obj = folium.Map(location=map_center, zoom_start=zoom_level)

# 在地图上标记地址
address = "新北市深坑區深坑街"
location = [25.001905494510424, 121.61478061023307]  # 地址的经纬度坐标
name = "深坑老街"
marker = folium.Marker(location=location, popup=address, tooltip=name)
marker.add_to(map_obj)

# 显示地图
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

# 创建地图对象
map_center = [24.863862428001276, 121.551357393035]  # 地图中心点的经纬度坐标
zoom_level = 14  # 地图缩放级别
map_obj = folium.Map(location=map_center, zoom_start=zoom_level)

# 在地图上标记地址
address = "新北市烏來區烏來街"
location = [24.863862428001276, 121.551357393035]  # 地址的经纬度坐标
name = "烏來老街"
marker = folium.Marker(location=location, popup=address, tooltip=name)
marker.add_to(map_obj)

# 显示地图
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

# 创建地图对象
map_center = [24.933814889718438, 121.36982303460637]  # 地图中心点的经纬度坐标
zoom_level = 14  # 地图缩放级别
map_obj = folium.Map(location=map_center, zoom_start=zoom_level)

# 在地图上标记地址
address = "新北市三峽區民權街37-147號"
location = [24.933814889718438, 121.36982303460637]  # 地址的经纬度坐标
name = "三峽老街"
marker = folium.Marker(location=location, popup=address, tooltip=name)
marker.add_to(map_obj)

# 显示地图
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

# 创建地图对象
map_center = [24.95428510222229, 121.34751466008522]  # 地图中心点的经纬度坐标
zoom_level = 14  # 地图缩放级别
map_obj = folium.Map(location=map_center, zoom_start=zoom_level)

# 在地图上标记地址
address = "新北市鶯歌區尖山埔路"
location = [24.95428510222229, 121.34751466008522]  # 地址的经纬度坐标
name = "三峽老街"
marker = folium.Marker(location=location, popup=address, tooltip=name)
marker.add_to(map_obj)

# 显示地图
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

# 创建地图对象
map_center = [24.88531025309031, 121.28743989140719]  # 地图中心点的经纬度坐标
zoom_level = 14  # 地图缩放级别
map_obj = folium.Map(location=map_center, zoom_start=zoom_level)

# 在地图上标记地址
address = "桃園市大溪區和平路、中山路"
location = [24.88531025309031, 121.28743989140719]  # 地址的经纬度坐标
name = "大溪老街"
marker = folium.Marker(location=location, popup=address, tooltip=name)
marker.add_to(map_obj)

# 显示地图
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

# 创建地图对象
map_center = [24.857106555537015, 121.82415199673419]  # 地图中心点的经纬度坐标
zoom_level = 14  # 地图缩放级别
map_obj = folium.Map(location=map_center, zoom_start=zoom_level)

# 在地图上标记地址
address = "宜蘭縣頭城鎮和平街"
location = [24.857106555537015, 121.82415199673419]  # 地址的经纬度坐标
name = "頭城老街"
marker = folium.Marker(location=location, popup=address, tooltip=name)
marker.add_to(map_obj)

# 显示地图
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
